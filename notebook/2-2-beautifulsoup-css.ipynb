# %% [markdown]
# # Beautifulsoup: 通过 CSS 类查找
# **首先我们还需要打开一个 [page](https://mofanpy.com/static/scraping/list.html)，然后我们可以在这个页面的 html 上应用 beautifulsoup。**

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# 如果是中文网页，需要解码，添加 decode('utf-8')
html = urlopen("https://mofanpy.com/static/scraping/list.html").read().decode('utf-8')
# 使用 BeautifulSoup 解析html
soup = BeautifulSoup(html, 'html.parser')
format_html = soup.prettify()
print(format_html)
# Out:
# <!DOCTYPE html>
# <html lang="cn">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    爬虫练习 列表 class | 莫烦 Python
#   </title>
#   <style>
#    .jan {
#       background-color: yellow;
#     }
#
#     .feb {
#       font-size: 25px;
#     }
#
#     .month {
#       color: red;
#     }
#   </style>
#  </head>
#  <body>
#   <h1>
#    列表 爬虫练习
#   </h1>
#   <p>
#    这是一个在
#    <a href="/">
#     莫烦 Python
#    </a>
#    的
#    <a href="/tutorials/data-manipulation/scraping/">
#     爬虫教程
#    </a>
#    里无敌简单的网页, 所有的 code 让你一目了然, 清晰无比.
#   </p>
#   <ul>
#    <li class="month">
#     一月
#    </li>
#    <ul class="jan">
#     <li>
#      一月一号
#     </li>
#     <li>
#      一月二号
#     </li>
#     <li>
#      一月三号
#     </li>
#    </ul>
#    <li class="feb month">
#     二月
#    </li>
#    <li class="month">
#     三月
#    </li>
#    <li class="month">
#     四月
#    </li>
#    <li class="month">
#     五月
#    </li>
#   </ul>
#  </body>
# </html>

# %% [markdown]
# **使用名为 lxml 的方法解析此 html，创建一个 soup 对象。查找所有具有 class=month 的“li”标签。**

# %%
soup = BeautifulSoup(html, features="html.parser")

# use class to narrow search
month = soup.find_all('li',{"class": "month"})
print(month)
for m in month:
    print(m.get_text())
# Out:
# [<li class="month">一月</li>, <li class="feb month">二月</li>, <li class="month">三月</li>, <li class="month">四月</li>, <li class="month">五月</li>]
# 一月
# 二月
# 三月
# 四月
# 五月

# %% [markdown]
# **或者使用一些有用的函数来查找标签。使用键访问找到的标签的属性，就像在 python 字典中所做的那样。**

# %%
jan = soup.find('ul', {"class": 'jan'})  
d_jan = jan.find_all('li')              
for d in d_jan:
    print(d.get_text())
# Out:
# 一月一号
# 一月二号
# 一月三号

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# 如果是中文网页，需要解码，添加 decode('utf-8')
html = urlopen("https://www.runoob.com/markdown/md-tutorial.html").read().decode('utf-8')
# 使用 BeautifulSoup 解析html
soup = BeautifulSoup(html, 'html.parser')
format_html = soup.prettify()
print(format_html)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Markdown 教程 | 菜鸟教程
#   </title>
#   <meta content="max-image-preview:large" name="robots"/>
#   <style>
#    img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#   </style>
#   <link href="http://www.runoob.com/markdown/md-tutorial.html" rel="canonical"/>
#   <meta content="Markdown 教程,markdown" name="keywords"/>
#   <meta content="Markdown 教程   Markdown 是一种轻量级标记语言，它允许人们使用易读易写的纯文本格式编写文档。 Markdown 语言在 2004 由约翰·格鲁伯（英语：John Gruber）创建。 Markdown 的设计理念是'易读易写'，让人们能够使用简单的纯文本格式来编写结构化文档。 Markdown 编写的文档可以导出 HTML 、Word、图像、PDF、Epub 等多种格式的文档。  Markdown.." name="description"/>
#   <link href="https://static.jyshare.com/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/wp-content/themes/runoob/style.css?v=1.187" media="all" rel="stylesheet" type="text/css">
#    <link href="https://static.jyshare.com/assets/font-awesome-4.7.0/css/font-awesome.min.css" media="all" rel="stylesheet"/>
#    <!--[if gte IE 9]><!-->
#    <script src="https://static.jyshare.com/assets/libs/jquery.min.js">
#    </script>
#    <!--<![endif]-->
#    <!--[if lt IE 9]>
#      <script src="https://lf6-cdn-tos.bytecdntp.com/cdn/expire-1-M/jquery/1.9.1/jquery.min.js"></script>
#      <script src="https://lf6-cdn-tos.bytecdntp.com/cdn/expire-1-M/html5shiv/r29/html5.min.js"></script>
#   <![endif]-->
#    <link href="https://static.jyshare.com/images/icon/mobile-icon.png" rel="apple-touch-icon"/>
#    <meta content="菜鸟教程" name="apple-mobile-web-app-title"/>
#   </link>
#  </head>
#  <body>
#   <!--  头部 -->
#   <div class="container logo-search">
#    <div class="col search row-search-mobile">
#     <form action="/">
#      <input autocomplete="off" class="placeholder" name="s" placeholder="搜索……"/>
#     </form>
#    </div>
#    <div class="row">
#     <div class="col logo">
#      <h1>
#       <a href="/">
#        菜鸟教程 -- 学的不仅是技术，更是梦想！
#       </a>
#      </h1>
#     </div>
#     <div class="col right-list">
#      <button class="btn btn-responsive-nav btn-inverse" data-target=".nav-main-collapse" data-toggle="collapse" id="pull" style="">
#       <i class="fa fa-navicon">
#       </i>
#      </button>
#     </div>
#     <div class="col search search-desktop last">
#      <div class="search-input">
#       <form action="/" target="_blank">
#        <input autocomplete="off" class="placeholder" id="s" name="s" placeholder="搜索……" style="height: 44px;"/>
#       </form>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- 导航栏 -->
#   <!-- 导航栏 -->
#   <div class="container navigation">
#    <div class="row">
#     <div class="col nav">
#      <ul class="pc-nav" id="runoob-detail-nav">
#       <li>
#        <a href="//www.runoob.com/">
#         首页
#        </a>
#       </li>
#       <li>
#        <a href="/html/html-tutorial.html">
#         HTML
#        </a>
#       </li>
#       <li>
#        <a href="/css/css-tutorial.html">
#         CSS
#        </a>
#       </li>
#       <li>
#        <a href="/js/js-tutorial.html">
#         JavaScript
#        </a>
#       </li>
#       <li>
#        <a data-id="vue" href="javascript:void(0);">
#         Vue
#        </a>
#       </li>
#       <li>
#        <a href="/react/react-tutorial.html">
#         React
#        </a>
#       </li>
#       <!--
# 				<li><a href="/nodejs/nodejs-tutorial.html">NodeJS</a></li>-->
#       <li>
#        <a href="/python3/python3-tutorial.html">
#         Python3
#        </a>
#       </li>
#       <!--
# 				<li><a href="/python/python-tutorial.html">Python2</a></li>
# 				-->
#       <li>
#        <a href="/java/java-tutorial.html">
#         Java
#        </a>
#       </li>
#       <li>
#        <a href="/cprogramming/c-tutorial.html">
#         C
#        </a>
#       </li>
#       <li>
#        <a href="/cplusplus/cpp-tutorial.html">
#         C++
#        </a>
#       </li>
#       <li>
#        <a href="/csharp/csharp-tutorial.html">
#         C#
#        </a>
#       </li>
#       <li>
#        <a data-id="aiNav" href="javascript:void(0);">
#         AI
#        </a>
#       </li>
#       <li>
#        <a href="/go/go-tutorial.html">
#         Go
#        </a>
#       </li>
#       <li>
#        <a href="/sql/sql-tutorial.html">
#         SQL
#        </a>
#       </li>
#       <li>
#        <a href="/linux/linux-tutorial.html">
#         Linux
#        </a>
#       </li>
#       <li>
#        <a href="/vscode/vscode-tutorial.html">
#         VS Code
#        </a>
#       </li>
#       <!--<li><a href="/jquery/jquery-tutorial.html">jQuery</a></li>-->
#       <li>
#        <a data-id="bootstrap" href="javascript:void(0);">
#         Bootstrap
#        </a>
#       </li>
#       <li>
#        <a href="/git/git-tutorial.html">
#         Git
#        </a>
#       </li>
#       <li>
#        <a href="/browser-history">
#         本地书签
#        </a>
#       </li>
#       <!--
# 				<li><a href="https://www.jyshare.com/front-end/9235/" target="_blank">AI 编程助理</a></li>	-->
#       <!--
#
# 				<li><a href="/w3cnote/knowledge-start.html" style="font-weight: bold;" onclick="_hmt.push(['_trackEvent', '星球', 'click', 'start'])" title="我的圈子">我的圈子</a></li>
# 				<li><a href="javascript:;" class="runoob-pop">登录</a></li>
# 				-->
#      </ul>
#      <ul class="mobile-nav">
#       <li>
#        <a href="//www.runoob.com/">
#         首页
#        </a>
#       </li>
#       <li>
#        <a href="/html/html-tutorial.html">
#         HTML
#        </a>
#       </li>
#       <li>
#        <a href="/css/css-tutorial.html">
#         CSS
#        </a>
#       </li>
#       <li>
#        <a href="/js/js-tutorial.html">
#         JS
#        </a>
#       </li>
#       <li>
#        <a href="/browser-history">
#         本地书签
#        </a>
#       </li>
#       <li>
#        <a class="search-reveal" href="javascript:void(0)">
#         Search
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="container sub-navigation sub-navigation-articles" style="display:none">
#    <div class="row">
#     <div class="col nav-sub">
#      <ul id="python">
#       <li class="cat-item">
#        <a href="/python3/python3-tutorial.html">
#         Python3 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/python/python-tutorial.html">
#         Python2 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#      </ul>
#      <ul id="vue">
#       <li class="cat-item">
#        <a href="/vue3/vue3-tutorial.html">
#         Vue3 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/vue/vue-tutorial.html">
#         vue2 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#      </ul>
#      <ul id="bootstrap">
#       <li class="cat-item">
#        <a href="/bootstrap/bootstrap-tutorial.html">
#         Bootstrap3 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/bootstrap4/bootstrap4-tutorial.html">
#         Bootstrap4 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/bootstrap5/bootstrap5-tutorial.html">
#         Bootstrap5 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/bootstrap/bootstrap-v2-tutorial.html">
#         Bootstrap2 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#      </ul>
#      <ul id="aiNav">
#       <li class="cat-item">
#        <a href="/ollama/ollama-tutorial.html">
#         Ollama 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/ml/ml-tutorial.html">
#         机器学习
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/pytorch/pytorch-tutorial.html">
#         PyTorch 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/tensorflow/tensorflow-tutorial.html">
#         TensorFlow 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/sklearn/sklearn-tutorial.html">
#         Sklearn 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#       <li class="cat-item">
#        <a href="/nlp/nlp-tutorial.html">
#         NLP 教程
#         <i aria-hidden="true" class="fa fa-external-link">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <!--  内容  -->
#   <div class="container main">
#    <!-- 中间 -->
#    <div class="row">
#     <div class="runoob-col-md2">
#      <div class="left-column">
#       <div class="tab" style="overflow: hidden;text-overflow: ellipsis;white-space: nowrap;">
#        <i aria-hidden="true" class="fa fa-list">
#        </i>
#        <span>
#         Markdown 教程
#        </span>
#        <a data-cate="231" href="javascript:void(0);" id="moon" title="夜间模式">
#         <i aria-hidden="true" class="fa fa-moon-o" style="line-height: 28px;font-size: 1.2em;margin: 2px 4px 0;">
#         </i>
#        </a>
#        <a data-cate="231" href="javascript:void(0);" id="sun" style="display:none;" title="日间模式">
#         <i aria-hidden="true" class="fa fa-sun-o" style="line-height: 28px;font-size: 1.2em;margin: 2px 4px 0;line-height: 28px;
# }">
#         </i>
#        </a>
#       </div>
#       <div class="sidebar-box gallery-list">
#        <div class="design" id="leftcolumn">
#         <a data-p="par" href="/markdown/md-tutorial.html" target="_top" title="Markdown 教程">
#          Markdown 教程
#         </a>
#         <a href="/markdown/md-editor.html" target="_top" title="Markdown 编辑器">
#          Markdown 编辑器
#         </a>
#         <a href="/markdown/md-first-file.html" target="_top" title="Markdown 第一个文件">
#          Markdown 第一个文件
#         </a>
#         <a data-p="par" href="/markdown/md-title.html" target="_top" title="Markdown  标题">
#          Markdown  标题
#         </a>
#         <a data-p="par" href="/markdown/md-paragraph.html" target="_top" title="Markdown 文本格式">
#          Markdown 文本格式
#         </a>
#         <a data-p="par" href="/markdown/md-lists.html" target="_top" title="Markdown 列表">
#          Markdown 列表
#         </a>
#         <a data-p="par" href="/markdown/md-block.html" target="_top" title="Markdown 引用块">
#          Markdown 引用块
#         </a>
#         <a data-p="par" href="/markdown/md-code.html" target="_top" title="Markdown 代码">
#          Markdown 代码
#         </a>
#         <a data-p="par" href="/markdown/md-link.html" target="_top" title="Markdown 链接">
#          Markdown 链接
#         </a>
#         <a data-p="par" href="/markdown/md-image.html" target="_top" title="Markdown 图片">
#          Markdown 图片
#         </a>
#         <a data-p="par" href="/markdown/md-table.html" target="_top" title="Markdown 表格">
#          Markdown 表格
#         </a>
#         <a data-p="par" href="/markdown/md-advance.html" target="_top" title="Markdown 高级技巧">
#          Markdown 高级技巧
#         </a>
#         <a data-p="par" href="/markdown/md-dividing-line.html" target="_top" title="Markdown 分割线">
#          Markdown 分割线
#         </a>
#         <a data-p="par" href="/markdown/md-math.html" target="_top" title="Markdown 数学公式">
#          Markdown 数学公式
#         </a>
#         <a data-p="par" href="/markdown/md-draw.html" target="_top" title="Markdown 图表绘制">
#          Markdown 图表绘制
#         </a>
#         <a data-p="par" href="/markdown/markdown-practices.html" target="_top" title="Markdown 实战">
#          Markdown 实战
#         </a>
#         <a data-p="par" href="/markdown/md-quiz.html" target="_top" title="Markdown 测验">
#          Markdown 测验
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col middle-column">
#      <div class="article">
#       <div class="previous-next-links">
#        <div class="previous-design-link">
#        </div>
#        <div class="next-design-link">
#         <a href="http://www.runoob.com/markdown/md-title.html" rel="next">
#          Markdown  标题
#         </a>
#         <i aria-hidden="true" class="fa fa-arrow-right" style="font-size:16px;">
#         </i>
#        </div>
#       </div>
#       <div class="article-heading-ad" style="display: block;">
#        <style>
#         /* 隐藏移动端广告 */
#   @media (max-width: 768px) {
#     .adsbygoogle {
#       display: none !important;
#     }
#   }
#        </style>
#        <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5751451760833794">
#        </script>
#        <!-- 728*90 固定 -->
#        <ins class="adsbygoogle" data-ad-client="ca-pub-5751451760833794" data-ad-slot="2147566827" style="display:inline-block;width:728px;height:90px">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#       <div class="article-body">
#        <div class="article-intro" id="content">
#         <h1>
#          Markdown 教程
#         </h1>
#         <div class="tutintro">
#          <img decoding="async" src="//www.runoob.com/wp-content/uploads/2019/03/iconfinder_markdown_298823.png"/>
#          <p>
#           Markdown 是一种轻量级标记语言，它允许人们使用易读易写的纯文本格式编写文档。
#          </p>
#          <p>
#           Markdown 语言在 2004 由约翰·格鲁伯（英语：John Gruber）创建。
#          </p>
#          <p>
#           Markdown 的设计理念是"易读易写"，让人们能够使用简单的纯文本格式来编写结构化文档。
#          </p>
#          <p>
#           Markdown 编写的文档可以导出 HTML 、Word、图像、PDF、Epub 等多种格式的文档。
#          </p>
#          <p>
#           Markdown 编写的文档后缀为
#           <span class="marked">
#            .md
#           </span>
#           ,
#           <span class="marked">
#            .markdown
#           </span>
#           。
#          </p>
#         </div>
#         <hr/>
#         <p>
#          Markdown 的核心特点包括：
#         </p>
#         <p>
#          <strong>
#           简洁性
#          </strong>
#          ：使用直观的符号来表示格式，比如用
#          <code>
#           <span class="marked">
#            #
#           </span>
#          </code>
#          表示标题，用
#          <code>
#           <span class="marked">
#            *
#           </span>
#          </code>
#          表示列表项。这些符号在视觉上就能传达其含义，即使不进行渲染也具有良好的可读性。
#         </p>
#         <p>
#          <strong>
#           可读性
#          </strong>
#          ：即使是纯文本形式的 Markdown 文档，也能清晰地展现文档的结构和层次。读者无需专门的软件就能理解内容的组织方式。
#         </p>
#         <p>
#          <strong>
#           便携性
#          </strong>
#          ：Markdown 文件是纯文本格式，可以在任何文本编辑器中打开和编辑，不依赖特定的软件或操作系统。
#         </p>
#         <p>
#          <strong>
#           转换性
#          </strong>
#          ：可以轻松转换为 HTML、PDF、Word 文档等多种格式，满足不同的发布需求。
#         </p>
#         <hr/>
#         <h2>
#          轻量级标记语言的概念
#         </h2>
#         <p>
#          标记语言是一种用特定符号来描述文档结构和格式的语言。传统的标记语言如 HTML 功能强大但语法复杂，而轻量级标记语言则简化了这一过程。
#         </p>
#         <p>
#          与 HTML 相比，Markdown 的优势在于：
#         </p>
#         <ul>
#          <li>
#           学习成本低，几分钟就能掌握基本语法
#          </li>
#          <li>
#           编写效率高，无需输入复杂的标签
#          </li>
#          <li>
#           专注内容，而非格式细节
#          </li>
#          <li>
#           版本控制友好，便于协作和变更追踪
#          </li>
#         </ul>
#         <hr/>
#         <h2>
#          Markdown 与 HTML 的关系
#          <p>
#           Markdown 并不是 HTML 的替代品，而是 HTML 的简化版本。实际上，Markdown 的最终目标就是转换为 HTML。两者的关系可以这样理解：
#          </p>
#          <pre>Markdown 源码 → 解析器 → HTML 输出 → 浏览器渲染</pre>
#          <p>
#           例如，当你写下：
#          </p>
#          <pre># 这是一个标题</pre>
#          <p>
#           它会被转换为：
#          </p>
#          <pre>&lt;h1&gt;这是一个标题&lt;/h1&gt;</pre>
#          <p>
#           重要的是，在 Markdown 中你可以直接使用 HTML 标签，这为复杂格式提供了灵活性。当 Markdown 的基础语法无法满足需求时，可以嵌入 HTML 代码来实现特定效果。
#          </p>
#          <hr/>
#          <h2>
#           为什么选择 Markdown
#          </h2>
#          <p>
#           <strong>
#            提高写作效率
#           </strong>
#           ：无需频繁使用鼠标进行格式设置，可以保持思路的连贯性。写作者可以专注于内容创作，而不被格式问题分散注意力。
#          </p>
#          <p>
#           <strong>
#            降低学习门槛
#           </strong>
#           ：相比于 LaTeX、HTML 等标记语言，Markdown 的语法极其简单，大多数人可以在一小时内掌握基本用法。
#          </p>
#          <p>
#           <strong>
#            广泛兼容性
#           </strong>
#           ：几乎所有的现代文本编辑器、代码编辑器、笔记应用都支持 Markdown。从简单的记事本到专业的 IDE，你都能找到 Markdown 的身影。
#          </p>
#          <p>
#           <strong>
#            版本控制友好
#           </strong>
#           ：由于是纯文本格式，Markdown 文件可以很好地与 Git 等版本控制系统配合，便于追踪文档的修改历史和团队协作。
#          </p>
#          <p>
#           <strong>
#            未来适应性
#           </strong>
#           ：即使特定的软件或平台消失，Markdown 文件作为纯文本仍然可以被访问和编辑，确保了内容的长期可用性。
#          </p>
#          <hr/>
#          <h2>
#           Markdown 的应用场景
#          </h2>
#          <h3>
#           技术文档编写
#          </h3>
#          <p>
#           在软件开发领域，Markdown 已成为技术文档的标准格式。它特别适合：
#          </p>
#          <ul>
#           <li>
#            <p>
#             <strong>
#              API 文档
#             </strong>
#             ：清晰的标题层次和代码块展示，让 API 说明既专业又易读。许多 API 文档生成工具（如 Swagger）都支持 Markdown 格式的描述。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              项目说明
#             </strong>
#             ：从安装指南到使用手册，Markdown 能够有效组织技术信息。代码示例、配置文件、命令行操作都能得到恰当的展示。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              开发规范
#             </strong>
#             ：团队的编码规范、设计准则、工作流程等都可以用 Markdown 编写，方便团队成员查阅和更新。
#            </p>
#           </li>
#          </ul>
#          <h3>
#           博客文章创作
#          </h3>
#          <p>
#           现代的博客平台和静态网站生成器大多支持 Markdown：
#          </p>
#          <ul>
#           <li>
#            <p>
#             <strong>
#              内容管理
#             </strong>
#             ：博主可以专注于内容创作，而不必担心复杂的 HTML 编码。文章的格式化通过简单的标记即可完成。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              平台迁移
#             </strong>
#             ：使用 Markdown 编写的文章可以轻松在不同平台间迁移，不会因为平台特有的格式而被锁定。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              离线编写
#             </strong>
#             ：可以在任何文本编辑器中离线编写文章，然后批量发布，提高了写作的灵活性。
#            </p>
#           </li>
#          </ul>
#          <h3>
#           GitHub README 文件
#          </h3>
#          <p>
#           GitHub 平台广泛使用 Markdown，特别是项目的 README 文件：
#          </p>
#          <ul>
#           <li>
#            <p>
#             <strong>
#              项目介绍
#             </strong>
#             ：清晰展示项目的目的、特性、使用方法等关键信息。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              安装指南
#             </strong>
#             ：通过代码块和列表，提供详细的安装和配置步骤。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              贡献指南
#             </strong>
#             ：说明如何参与项目开发，包括代码规范、提交流程等。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              问题跟踪
#             </strong>
#             ：在 Issues 和 Pull Requests 中，开发者使用 Markdown 来描述问题、提供解决方案。
#            </p>
#           </li>
#          </ul>
#          <h3>
#           笔记记录和知识管理
#          </h3>
#          <p>
#           Markdown 正成为数字笔记的首选格式：
#          </p>
#          <ul>
#           <li>
#            <p>
#             <strong>
#              学习笔记
#             </strong>
#             ：支持数学公式、代码高亮、图表等多种内容类型，适合技术学习和知识整理。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              会议记录
#             </strong>
#             ：清晰的标题结构和列表格式，让会议要点一目了然。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              知识库建设
#             </strong>
#             ：企业和个人都在使用 Markdown 构建知识库，通过链接和标签组织信息。
#            </p>
#           </li>
#          </ul>
#          <h3>
#           在线写作平台
#          </h3>
#          <p>
#           越来越多的写作平台开始支持 Markdown：
#          </p>
#          <ul>
#           <li>
#            <p>
#             <strong>
#              GitHub、简书、知乎
#             </strong>
#             ：这些平台的编辑器支持 Markdown 语法，让创作者能够快速格式化文章。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              GitBook、Notion
#             </strong>
#             ：专业的文档和笔记平台，原生支持 Markdown，提供强大的组织和协作功能。
#            </p>
#           </li>
#           <li>
#            <p>
#             <strong>
#              静态博客生成器
#             </strong>
#             ：Jekyll、Hugo、Hexo 等工具让用户能够用 Markdown 创建专业的网站。
#            </p>
#           </li>
#          </ul>
#          <hr/>
#          <h2>
#           有用的书籍
#          </h2>
#          <p>
#           《了不起的Markdown》：
#          </p>
#          <ul>
#           <li>
#            <a href="https://union-click.jd.com/jdc?e=618%7Cpc%7C&amp;p=JF8BAM0JK1olXwUFU1xdCE4TBl8IGFwSVQUEUW4ZVxNJXF9RXh5UHw0cSgYYXBcIWDoXSQVJQwYBU1lVC00SHDZNRwYlIXBjCCEWQUl0dmhjaBBFWVp7FABVXkcbM244GFkUXwYyZF5aOBl529m-w_6kQdKo24vVn3sWM28PHV0cVQ4GVl5aAE0nBG8BKx5NDVlCDBcFV3snM2w4HFscSQBwFQxJDjknM284GGsVVA4DV15dAU8LA24LGVMJXQEEUldVAE4eAG0PHWsXXAcGXW5t" rel="noopener noreferrer" target="_blank">
#             京东
#            </a>
#           </li>
#          </ul>
#          <!-- 其他扩展 -->
#         </h2>
#        </div>
#       </div>
#       <div class="archive-list" style="display:none;font-size: 14px;line-height: 1.8;margin-top: 20px;padding: 10px;">
#        <div class="archive-list-item">
#         <div class="post-intro" id="ai-info" style="width: 100%;">
#          AI 思考中...
#         </div>
#        </div>
#       </div>
#       <div class="previous-next-links">
#        <div class="previous-design-link">
#        </div>
#        <div class="next-design-link">
#         <a href="http://www.runoob.com/markdown/md-title.html" rel="next">
#          Markdown  标题
#         </a>
#         <i aria-hidden="true" class="fa fa-arrow-right" style="font-size:16px;">
#         </i>
#        </div>
#       </div>
#       <div class="sidebar-box">
#        <style>
#         .responsive_ad1 { display:none; }
# @media(min-width: 800px) { .responsive_ad1 {  display:block;margin:0 auto;} }
#        </style>
#        <div class="responsive_ad1" id="ad-336280">
#         <!-- 336*280 固定 -->
#         <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5751451760833794">
#         </script>
#         <!-- 移动版 自动调整 -->
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5751451760833794" data-ad-format="auto" data-ad-slot="1691338467" data-full-width-responsive="true" style="display:block">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#       </div>
#       <!-- 笔记列表 -->
#       <style>
#        .wrapper {
#   /*text-transform: uppercase; */
#   background: #ececec;
#   color: #555;
#   cursor: pointer;
#   font-family: "Gill Sans", Impact, sans-serif;
#   font-size: 20px;
#   position: relative;
#   text-align: center;
#   width: 200px;
#   -webkit-transform: translateZ(0); /* webkit flicker fix */
#   -webkit-font-smoothing: antialiased; /* webkit text rendering fix */
# }
#
# .wrapper .tooltip {
#   white-space: nowrap;
#   font-size: 14px;
#   text-align: left;
#   background: #96b97d;
#   bottom: 100%;
#   color: #fff;
#   display: block;
#   left: -25px;
#   margin-bottom: 15px;
#   opacity: 0;
#   padding: 14px;
#   pointer-events: none;
#   position: absolute;
#
#   -webkit-transform: translateY(10px);
#      -moz-transform: translateY(10px);
#       -ms-transform: translateY(10px);
#        -o-transform: translateY(10px);
#           transform: translateY(10px);
#   -webkit-transition: all .25s ease-out;
#      -moz-transition: all .25s ease-out;
#       -ms-transition: all .25s ease-out;
#        -o-transition: all .25s ease-out;
#           transition: all .25s ease-out;
#   -webkit-box-shadow: 2px 2px 6px rgba(0, 0, 0, 0.28);
#      -moz-box-shadow: 2px 2px 6px rgba(0, 0, 0, 0.28);
#       -ms-box-shadow: 2px 2px 6px rgba(0, 0, 0, 0.28);
#        -o-box-shadow: 2px 2px 6px rgba(0, 0, 0, 0.28);
#           box-shadow: 2px 2px 6px rgba(0, 0, 0, 0.28);
# }
# .tooltip a {
# 	color:#fff;
# }
# /* This bridges the gap so you can mouse into the tooltip without it disappearing */
# .wrapper .tooltip:before {
#   bottom: -20px;
#   content: " ";
#   display: block;
#   height: 20px;
#   left: 0;
#   position: absolute;
#   width: 100%;
# }
#
# /* CSS Triangles - see Trevor's post */
# .wrapper .tooltip:after {
#   border-left: solid transparent 10px;
#   border-right: solid transparent 10px;
#   border-top: solid #96b97d 10px;
#   bottom: -10px;
#   content: " ";
#   height: 0;
#   left: 20%;
#   margin-left: -13px;
#   position: absolute;
#   width: 0;
# }
# .wrapper .tooltip1 {
# 	margin-left: 50px;
# 	padding-top: 0px;
# }
# /*
# .wrapper:hover .tooltip {
#   opacity: 1;
#   pointer-events: auto;
#   -webkit-transform: translateY(0px);
#      -moz-transform: translateY(0px);
#       -ms-transform: translateY(0px);
#        -o-transform: translateY(0px);
#           transform: translateY(0px);
# }
# */
# /* IE can just show/hide with no transition */
# .lte8 .wrapper .tooltip {
#   display: none;
# }
#
# .lte8 .wrapper:hover .tooltip {
#   display: block;
# }
#       </style>
#       <link href="https://static.jyshare.com/assets/upvotejs/dist/upvotejs/upvotejs.css" rel="stylesheet"/>
#       <script src="https://static.jyshare.com/assets/upvotejs/dist/upvotejs/upvotejs.vanilla.js">
#       </script>
#       <script src="https://static.jyshare.com/assets/upvotejs/dist/upvotejs/upvotejs.jquery.js">
#       </script>
#       <div class="no_webshot" id="respond">
#        <div class="comment-signarea" style=" padding: 20px 20px;">
#         <h3 class="text-muted" id="share_code" style="color: #799961;">
#          <i aria-hidden="true" class="fa fa-pencil-square-o">
#          </i>
#          点我分享笔记
#         </h3>
#         <!--
# 	<p style="font-size:14px;">笔记需要是本篇文章的内容扩展！</p><br>
# 	<p style="font-size:12px;"><a href="//www.runoob.com/tougao" target="_blank">文章投稿，可点击这里</a></p>
# 	<p style="font-size:14px;"><a href="/w3cnote/runoob-user-test-intro.html#invite" target="_blank">注册邀请码获取方式</a></p>
# 		<h3 class="text-muted"><i class="fa fa-info-circle" aria-hidden="true"></i> 分享笔记前必须<a href="javascript:;" class="runoob-pop">登录</a>！</h3>
# 		<p><a href="/w3cnote/runoob-user-test-intro.html#invite" target="_blank">注册邀请码获取方式</a></p>-->
#        </div>
#        <form action="/wp-content/themes/runoob/option/addnote.php" id="commentform" method="post" style="display:none;">
#         <div class="comt">
#          <div class="comt-title">
#           <i aria-hidden="true" class="fa fa-user-circle" style="font-size:36px;">
#           </i>
#           <p>
#            <a href="javascript:;" id="cancel-comment-reply-link">
#             取消
#            </a>
#           </p>
#          </div>
#          <div class="comt-box">
#           <div id="mded">
#           </div>
#           <div class="comt-ctrl">
#            <div class="comt-tips">
#             <input id="comment_post_ID" name="comment_post_ID" type="hidden" value="21366">
#              <input id="comment_parent" name="comment_parent" type="hidden" value="0">
#              </input>
#             </input>
#            </div>
#            <button id="submit" name="submit" tabindex="5" type="submit">
#             <i aria-hidden="true" class="fa fa-pencil">
#             </i>
#             分享笔记
#            </button>
#           </div>
#          </div>
#          <div class="comt-comterinfo">
#           <ul id="comment-author-info">
#            <li class="form-inline">
#             <label class="hide" for="author">
#              昵称
#             </label>
#             <input class="ipt" id="author" name="author" placeholder="昵称" tabindex="2" type="text" value=""/>
#             <span class="text-muted">
#              昵称 (必填)
#             </span>
#            </li>
#            <li class="form-inline">
#             <label class="hide" for="email">
#              邮箱
#             </label>
#             <input class="ipt" id="email" name="email" placeholder="邮箱" tabindex="3" type="text" value=""/>
#             <span class="text-muted">
#              邮箱 (必填)
#             </span>
#            </li>
#            <li class="form-inline">
#             <label class="hide" for="url">
#              引用地址
#             </label>
#             <input class="ipt" id="url" name="url" placeholder="引用地址" tabindex="4" type="text" value=""/>
#             <span class="text-muted">
#              引用地址
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </form>
#       </div>
#       <script type="text/javascript">
#        $(function() {
# 	//初始化编辑器
#
# 	var editor = new Simditor({
# 	  textarea: $('#mded'),
# 	  placeholder: '写笔记...',
# 	  upload:false,
# 	 // upload: {url:'/api/comment_upload_file.php',params: null,fileKey: 'upload_file',connectionCount: 1,leaveConfirm: '文件正在上传，您确定离开?'},
# 	  defaultImage: 'https://www.runoob.com/images/logo.png',
# 	  codeLanguages: '',
# 	  autosave: 'editor-content',
# 	  toolbar: [  'bold','code','ul','ol','image' ]
# 	});
# 	editor.on('selectionchanged', function() {
# 		$(".code-popover").hide();
# 	});
#
# 	// 提交数据
# 	$("#share_code").click(function() {
# 		$(".comment-signarea").hide();
# 		$("#commentform").show();
#
# 	});
# 	$("#user_add_note").click(function() {
# 		$(".comment-signarea").hide();
# 		$("#commentform").show();
# 		$('html, body').animate({
#        	    scrollTop: $("#respond").offset().top
#     	}, 200);
# 	});
#
# 	// 提交笔记
# 	var commentform=$('#commentform');
# 	commentform.prepend('<div id="comment-status" style="display:none;" ></div>');
# 	var statusdiv=$('#comment-status');
#
# 	commentform.submit(function(e){
# 		e.preventDefault();
# 		var noteContent = editor.getValue();
# 		// console.log(noteContent);
# 		noteContent = noteContent.replace(/<pre><code>/g,"<pre>");
# 		noteContent = noteContent.replace(/<\/code><\/pre>/g,"</pre>");
#
# 		// 系列化表单数据
# 		var comment_parent = 0;
# 		var is_user_logged_in = $("#is_user_logged_in").val();
# 		var comment_post_ID =  21366;
# 		var _wp_unfiltered_html_comment = $("#_wp_unfiltered_html_comment").val();
# 		var comment = noteContent;
# 		var author = $("#author").val();
# 		var url = $("#url").val();
# 		var email = $("#email").val();
# 		if(isBlank(author) && is_user_logged_in==0) {
# 			statusdiv.html('<p  class="ajax-error">请输入昵称！</p>').show();
# 		} else if(isBlank(email)  && is_user_logged_in==0) {
# 			statusdiv.html('<p  class="ajax-error">请输入邮箱！</p>').show();
# 		} else {
# 			// var formdata=commentform.serialize() + "&comment=" + noteContent ;
# 			// 添加状态信息
# 			statusdiv.html('<p>Processing...</p>').show();
# 			// 获取表单提交地址
# 			var formurl=commentform.attr('action');
#
# 			// 异步提交
# 			$.ajax({
# 					type: 'post',
# 					url: formurl,
# 					dataType:'json',
# 					data: {"comment_parent":comment_parent,"comment_post_ID":comment_post_ID, "_wp_unfiltered_html_comment":_wp_unfiltered_html_comment,"comment":comment,"url":url, "email":email,"author":author},
# 					error: function(XMLHttpRequest, textStatus, errorThrown){
# 					statusdiv.html('<p class="ajax-error" >数据不完整或表单提交太快了！</p>').show();
# 				},
# 				success: function(data, textStatus){
# 					if(data.errorno=="0") {
# 						$("#submit").prop('disabled', true);
# 						statusdiv.html('<p class="ajax-success" >笔记已提交审核，感谢分享笔记！</p>').show();
# 						alert('笔记已提交审核，感谢分享笔记！');
# 					}else{
# 						statusdiv.html('<p class="ajax-error" >'+data.msg+'</p>').show();
# 					}
# 					commentform.find('textarea[name=comment]').val('');
# 				}
# 			});
# 			setTimeout(function(){
# 		        $("#submit").prop('disabled', false);
# 		    }, 10*1000);
# 		}
# 		return false;
#
# 	});
# 	$(".comt-author").click(function() {
# 		href = $(this).children("a").attr("href");
# 		if(href.indexOf("/note/")!=-1) {
# 			var win = window.open(href, '_blank');
#   			win.focus();
# 		}
# 	});
# 	$(".comt-meta span").hover(function(){
# 		$(this).children(".tooltip").css({ "opacity": 1, "pointer-events": "auto"});
# 	},function(){
# 		$(this).children(".tooltip").removeAttr("style");
# 	});
# 	/*
# 	$(".wrapper i").hover(function(){
# 		$(this).siblings(".tooltip").css({ "opacity": 1, "pointer-events": "auto"});
# 	},function(){
# 		$(this).siblings(".tooltip").css({ "opacity": 0, "pointer-events": "auto"});
# 	});
# 	*/
# 	//Upvote.create('runoobvote-id', {callback: vote_callback});
# 	var ajaxurl = 'https://www.runoob.com/wp-admin/admin-ajax.php';
# 	var callback = function(data) {
# 		//console.log($('#runoobvote-id').upvote('upvoted'));
# 		//console.log($('#runoobvote-id').upvote('downvoted'));
# 		//console.log(data);
# 		_vote_action = data.action;
# 		id_arr = data.id.split('-');
# 		um_id= id_arr[2];
# 		//console.log(um_id);
#
# 		var re = /^[1-9]+/;
# 		if (re.test(um_id)) {
# 			var ajax_data = {
# 				_vote_action: _vote_action,
# 				action: "pinglun_zan",
# 				um_id: um_id,
# 				um_action: "ding"
# 			};
# 			//console.log(ajax_data);
# 			$.post(ajaxurl,ajax_data,function(status){
# 				//if(status.vote_num>999) {
# 				//	_voteHtml = '<span style="display: block; text-align: center;font-size: 20px; color: #6a737c; margin: 8px 0;">'+kFormatter(status.vote_num) +'</span>';
# 				//	$("#runoobvote-id-" + um_id + " .count").hide().after(_voteHtml);
# 				//}
#
# 			});
# 		}
# 	};
# 	if($('#comments').length && $('.upvotejs').length){
# 		$('.upvotejs').upvote({id: 21366, callback: callback});
#
# 		$.post(ajaxurl,{"action":"pinglun_zan","postid":21366},function(data){
# 			$(data).each(function(key,value) {
# 				$("#runoobvote-id-" + value.commid + " .upvote").addClass(value.upvotejs_class);
# 				$("#runoobvote-id-" + value.commid + " .downvote").addClass(value.downvote_class);
# 				$("#runoobvote-id-" + value.commid + " .count").text(value.upvote_count);
# 			})
# 		},'json');
#
# 	}
#
#
# });
# function isBlank(str) {
#     return (!str || /^\s*$/.test(str));
# }
# function kFormatter(num) {
# 	// return num;
#     return Math.abs(num) > 999 ? Math.sign(num)*((Math.abs(num)/1000).toFixed(1)) + 'k' : Math.sign(num)*Math.abs(num)
# }
#       </script>
#       <link href="/wp-content/themes/runoob/assets/css/qa.css?1.45" rel="stylesheet"/>
#       <link href="https://static.jyshare.com/assets/simditor/2.3.6/styles/simditor.min.css" rel="stylesheet" type="text/css">
#        <script src="https://static.jyshare.com/assets/simditor/2.3.6/scripts/module.js" type="text/javascript">
#        </script>
#        <script src="https://static.jyshare.com/assets/simditor/2.3.6/scripts/hotkeys.js" type="text/javascript">
#        </script>
#        <script src="https://static.jyshare.com/assets/simditor/2.3.6/scripts/uploader.js" type="text/javascript">
#        </script>
#        <script src="https://static.jyshare.com/assets/simditor/2.3.6/scripts/simditor.min.js" type="text/javascript">
#        </script>
#        <script src="https://static.jyshare.com/assets/simditor/2.3.6/scripts/simditor-autosave.js" type="text/javascript">
#        </script>
#       </link>
#      </div>
#     </div>
#     <!-- 右边栏 -->
#     <div class="fivecol last right-column">
#      <style>
#       .sidebar-tree .double-li {
#     width:300px;
# }
# .sidebar-tree .double-li li {
#     width: 44%;
#     line-height: 1.5em;
#     border-bottom: 1px solid #ccc;
#     float: left;
#     display: inline;
# }
#      </style>
#      <div class="sidebar-box re-box re-box-large">
#       <div class="sidebar-box recommend-here" style="margin: 0 auto;">
#        <a href="javascript:void(0);" style="font-size: 16px; color:#64854c;font-weight:bold;">
#         <i aria-hidden="true" class="fa fa-list">
#         </i>
#         分类导航
#        </a>
#       </div>
#       <div class="sidebar-box sidebar-cate">
#        <div class="sidebar-tree">
#         <ul>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            HTML / CSS
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/html/html-tutorial.html" title="HTML 教程">
#              HTML 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/html/html5-intro.html" title="HTML5 教程">
#              HTML5 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/css/css-tutorial.html" title="CSS 教程">
#              CSS 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/css3/css3-tutorial.html" title="CSS3 教程">
#              CSS3 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/tailwindcss/tailwindcss-tutorial.html" title="Tailwind CSS 教程">
#              Tailwind CSS 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/bootstrap4/bootstrap4-tutorial.html" title="Bootstrap4 教程">
#              Bootstrap4 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/bootstrap5/bootstrap5-tutorial.html" title="Bootstrap5 教程">
#              Bootstrap5 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/font-awesome/fontawesome-tutorial.html" title="Font Awesome 教程">
#              Font Awesome 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/foundation/foundation-tutorial.html" title="Foundation 教程">
#              Foundation 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            JavaScript
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/js/js-tutorial.html" title="JavaScript 教程">
#              JavaScript 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/htmldom/htmldom-tutorial.html" title="HTML DOM 教程">
#              HTML DOM 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/jquery/jquery-tutorial.html" title="jQuery 教程">
#              jQuery 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/angularjs/angularjs-tutorial.html" title="AngularJS 教程">
#              AngularJS 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/angularjs2/angularjs2-tutorial.html" title="AngularJS2 教程">
#              AngularJS2 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/vue2/vue-tutorial.html" title="Vue.js 教程">
#              Vue.js 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/vue3/vue3-tutorial.html" title="Vue3 教程">
#              Vue3 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/react/react-tutorial.html" title="React 教程">
#              React 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/nextjs/nextjs-tutorial.html" title="Next.js 教程">
#              Next.js 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/typescript/ts-tutorial.html" title="TypeScript 教程">
#              TypeScript 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/jqueryui/jqueryui-tutorial.html" title="jQuery UI 教程">
#              jQuery UI 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/jeasyui/jqueryeasyui-tutorial.html" title="jQuery EasyUI 教程">
#              jQuery EasyUI 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/nodejs/nodejs-tutorial.html" title="Node.js 教程">
#              Node.js 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/ajax/ajax-tutorial.html" title="AJAX 教程">
#              AJAX 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/json/json-tutorial.html" title="JSON 教程">
#              JSON 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/echarts/echarts-tutorial.html" title="Echarts 教程">
#              Echarts 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/chartjs/chartjs-tutorial.html" title="Chart.js 教程">
#              Chart.js 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/highcharts/highcharts-tutorial.html" title="Highcharts 教程">
#              Highcharts 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/googleapi/google-maps-basic.html" title="Google 地图 教程">
#              Google 地图 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            服务端
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/python3/python3-tutorial.html" title="Python 教程">
#              Python 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/python/python-tutorial.html" title="Python2.x 教程">
#              Python2.x 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/linux/linux-tutorial.html" title="Linux 教程">
#              Linux 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/docker/docker-tutorial.html" title="Docker 教程">
#              Docker 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/ruby/ruby-tutorial.html" title="Ruby 教程">
#              Ruby 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/java/java-tutorial.html" title="Java 教程">
#              Java 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/c/c-tutorial.html" title="C 教程">
#              C 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/cplusplus/cpp-tutorial.html" title="C++ 教程">
#              C++ 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/perl/perl-tutorial.html" title="Perl 教程">
#              Perl 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/servlet/servlet-tutorial.html" title="Servlet 教程">
#              Servlet 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/jsp/jsp-tutorial.html" title="JSP 教程">
#              JSP 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/lua/lua-tutorial.html" title="Lua 教程">
#              Lua 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/rust/rust-tutorial.html" title="Rust 教程">
#              Rust 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/zig/zig-tutorial.html" title="Zig 教程">
#              Zig 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/scala/scala-tutorial.html" title="Scala 教程">
#              Scala 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/go/go-tutorial.html" title="Go 教程">
#              Go 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/php/php-tutorial.html" title="PHP 教程">
#              PHP 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/data-structures/data-structures-tutorial.html" title="数据结构与算法">
#              数据结构与算法
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/django/django-tutorial.html" title="Django 教程">
#              Django 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/fastapi/fastapi-tutorial.html" title="FastAPI 教程">
#              FastAPI 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/flask/flask-tutorial.html" title="Flask 教程">
#              Flask 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/pillow/pillow-tutorial.html" title="Pillow 教程">
#              Pillow 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/w3cnote/zookeeper-tutorial.html" title="Zookeeper 教程">
#              Zookeeper 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/design-pattern/design-pattern-tutorial.html" title="设计模式">
#              设计模式
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/regexp/regexp-tutorial.html" title="正则表达式">
#              正则表达式
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/maven/maven-tutorial.html" title="Maven 教程">
#              Maven 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/cmake/cmake-tutorial.html" title="CMake 教程">
#              CMake 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/w3cnote/verilog-tutorial.html" title="Verilog 教程">
#              Verilog 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/asp/asp-tutorial.html" title="ASP 教程">
#              ASP 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/appml/appml-tutorial.html" title="AppML 教程">
#              AppML 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/vbscript/vbscript-tutorial.html" title="VBScript 教程">
#              VBScript 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            数据库
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/sql/sql-tutorial.html" title="SQL 教程">
#              SQL 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/mysql/mysql-tutorial.html" title="MySQL 教程">
#              MySQL 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/postgresql/postgresql-tutorial.html" title="PostgreSQL 教程">
#              PostgreSQL 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/sqlite/sqlite-tutorial.html" title="SQLite 教程">
#              SQLite 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/mongodb/mongodb-tutorial.html" title="MongoDB 教程">
#              MongoDB 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/redis/redis-tutorial.html" title="Redis 教程">
#              Redis 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/Memcached/Memcached-tutorial.html" title="Memcached 教程">
#              Memcached 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            AI &amp; 数据分析
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/python3/python3-tutorial.html" title="Python 教程">
#              Python 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/numpy/numpy-tutorial.html" title="NumPy 教程">
#              NumPy 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/pandas/pandas-tutorial.html" title="Pandas 教程">
#              Pandas 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/matplotlib/matplotlib-tutorial.html" title="Matplotlib 教程">
#              Matplotlib 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/scipy/scipy-tutorial.html" title="Scipy 教程">
#              Scipy 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/pytorch/pytorch-tutorial.html" title="Pytorch 教程">
#              Pytorch 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/tensorflow/tensorflow-tutorial.html" title="TensorFlow 教程">
#              TensorFlow 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/ollama/ollama-tutorial.html" title="Ollama 教程">
#              Ollama 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/ml/ml-tutorial.html" title="机器 教程">
#              机器 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/sklearn/sklearn-tutorial.html" title="scikit-learn 教程">
#              scikit-learn 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/r/r-tutorial.html" title="R 教程">
#              R 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/opencv/opencv-tutorial.html" title="OpenCV 教程">
#              OpenCV 教程
# ...
#              Swift 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/jquerymobile/jquerymobile-tutorial.html" title="jQuery Mobile 教程">
#              jQuery Mobile 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/ionic/ionic-tutorial.html" title="ionic 教程">
#              ionic 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/kotlin/kotlin-tutorial.html" title="Kotlin 教程">
#              Kotlin 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            开发工具
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/vscode/vscode-tutorial.html" title="VS Code 教程">
#              VS Code 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/pycharm/pycharm-tutorial.html" title="PyCharm 教程">
#              PyCharm 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/swagger/swagger-tutorial.html" title="Swagger 教程">
#              Swagger 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/restfulapi/restful-api-tutorial.html" title="RESTful API 教程">
#              RESTful API 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/eclipse/eclipse-tutorial.html" title="Eclipse 教程">
#              Eclipse 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/git/git-tutorial.html" title="Git 教程">
#              Git 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/svn/svn-tutorial.html" title="Svn 教程">
#              Svn 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/markdown/md-tutorial.html" title="Markdown 教程">
#              Markdown 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            XML 教程
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/xml/xml-tutorial.html" title="XML 教程">
#              XML 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/dtd/dtd-tutorial.html" title="DTD 教程">
#              DTD 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/dom/dom-tutorial.html" title="XML DOM 教程">
#              XML DOM 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/xsl/xsl-tutorial.html" title="XSLT 教程">
#              XSLT 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/xpath/xpath-tutorial.html" title="XPath 教程">
#              XPath 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/xquery/xquery-tutorial.html" title="XQuery 教程">
#              XQuery 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/xlink/xlink-tutorial.html" title="XLink 教程">
#              XLink 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/xlink/xlink-tutorial.html" title="XPointer 教程">
#              XPointer 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/schema/schema-tutorial.html" title="XML Schema 教程">
#              XML Schema 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/xslfo/xslfo-tutorial.html" title="XSL-FO 教程">
#              XSL-FO 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/svg/svg-tutorial.html" title="SVG 教程">
#              SVG 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            ASP.NET
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/aspnet/aspnet-tutorial.html" title="ASP.NET 教程">
#              ASP.NET 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/csharp/csharp-tutorial.html" title="C# 教程">
#              C# 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/powershell/powershell-tutorial.html" title="PowerShell 教程">
#              PowerShell 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/aspnet/webpages-intro.html" title="Web Pages 教程">
#              Web Pages 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/aspnet/razor-intro.html" title="Razor 教程">
#              Razor 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/aspnet/mvc-intro.html" title="MVC 教程">
#              MVC 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/aspnet/aspnet-intro.html" title="Web Forms 教程">
#              Web Forms 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            Web Service
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/webservices/webservices-tutorial.html" title="Web Service 教程">
#              Web Service 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/wsdl/wsdl-tutorial.html" title="WSDL 教程">
#              WSDL 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/soap/soap-tutorial.html" title="SOAP 教程">
#              SOAP 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/rss/rss-tutorial.html" title="RSS 教程">
#              RSS 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/rdf/rdf-tutorial.html" title="RDF 教程">
#              RDF 教程
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li style="margin: 0;">
#           <a class="tit" href="javascript:void(0);">
#            网站建设
#           </a>
#           <ul class="double-li">
#            <li>
#             <a href="//www.runoob.com/http/http-tutorial.html" title="HTTP 教程">
#              HTTP 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/web/web-buildingprimer.html" title="网站建设指南">
#              网站建设指南
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/browsers/browser-information.html" title="浏览器信息">
#              浏览器信息
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/np/np-tutorial.html" title="网络协议">
#              网络协议
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/hosting/hosting-tutorial.html" title="网站主机教程">
#              网站主机教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/tcpip/tcpip-tutorial.html" title="TCP/IP 教程">
#              TCP/IP 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/w3c/w3c-tutorial.html" title="W3C 教程">
#              W3C 教程
#             </a>
#            </li>
#            <li>
#             <a href="//www.runoob.com/quality/quality-tutorial.html" title="网站品质">
#              网站品质
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <br/>
#      <div class="sidebar-box re-box re-box-large">
#       <div class="sidebar-box recommend-here">
#        <a href="javascript:void(0);">
#         Advertisement
#        </a>
#       </div>
#       <div class="re-600160" id="sidebar-right-re">
#        <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#        </script>
#        <!-- 侧栏1 -->
#        <ins class="adsbygoogle" data-ad-client="ca-pub-5751451760833794" data-ad-slot="4106274865" style="display:inline-block;width:160px;height:600px">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    var aid = 21366;
# function coll() {
# 	$.post( '/wp-content/themes/runoob/option/user/userinfo.php', {aid:aid, action:"collarticle", opt:'add'},function( data ) {
# 		if(data.error==0) {
# 			$("#content").find("h1:first").find("a").attr("href","javascript:void(0);");
# 			$("#content").find("h1:first").find("img").attr("src","http://www.runoob.com/wp-content/themes/runoob/assets/img/coll2.png").css({width:32+"px",height:32+"px"});
# 		}
# 		alert(data.msg);
# 	},'json');
# }
#   </script>
#   <!-- 反馈对话框开始 -->
#   <script src="/wp-content/themes/runoob/assets/feedback/stable/2.0/feedback.js?1.0">
#   </script>
#   <link href="/wp-content/themes/runoob/assets/feedback/stable/2.0/feedback.css?1.0" rel="stylesheet">
#    <script type="text/javascript">
#     $(document).ready(function() {
#     // 获取窗口宽度
#     var windowWidth = $(window).width();
#
#     // 设置一个阈值，例如 768px，根据实际需要调整
#     var mobileThreshold = 768;
#
#     // 判断是否为移动端
#     if (windowWidth < mobileThreshold) {
#         // 在移动端执行的代码
#         $(".article-heading-ad").show();
#     } else {
#         // 在非移动端执行的代码
# 		$(".article-heading-ad").show();
#     }
#
# });
#    </script>
#    <!-- 底部 -->
#    <div class="mar-t50" id="footer">
#     <div class="runoob-block">
#      <div class="runoob cf">
#       <dl>
#        <dt>
#         在线实例
#        </dt>
#        <dd>
#         ·
#         <a href="/html/html-examples.html" target="_blank">
#          HTML 实例
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/css/css-examples.html" target="_blank">
#          CSS 实例
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/js/js-examples.html" target="_blank">
#          JavaScript 实例
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/ajx/ajax-examples.html" target="_blank">
#          Ajax 实例
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/jquery/jquery-examples.html" target="_blank">
#          jQuery 实例
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/xml/xml-examples.html" target="_blank">
#          XML 实例
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/java/java-examples.html" target="_blank">
#          Java 实例
#         </a>
#        </dd>
#       </dl>
#       <dl>
#        <dt>
#         字符集&amp;工具
#        </dt>
#        <dd>
#         ·
#         <a href="/charsets/html-charsets.html" target="_blank">
#          HTML 字符集设置
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/tags/html-ascii.html" target="_blank">
#          HTML ASCII 字符集
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="https://www.jyshare.com/front-end/6939/" target="_blank">
#          JS 混淆/加密
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="https://www.jyshare.com/front-end/6232/" target="_blank">
#          PNG/JPEG 图片压缩
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/tags/html-colorpicker.html" target="_blank">
#          HTML 拾色器
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="https://www.jyshare.com/front-end/53" target="_blank">
#          JSON 格式化工具
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="https://www.jyshare.com/front-end/6680/" target="_blank">
#          随机数生成器
#         </a>
#        </dd>
#       </dl>
#       <dl>
#        <dt>
#         最新更新
#        </dt>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/vscode/vscode-mcp-servers.html" title="VS Code MCP 服务">
#          VS Code MCP 服务
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/linux/windows-wsl-linux.html" title="Windows WSL 安装 Linux">
#          Windows WSL 安...
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/powershell/powershell-practice.html" title="PowerShell 实际应用">
#          PowerShell 实际...
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/powershell/powershell-script.html" title="PowerShell 脚本编写">
#          PowerShell 脚本...
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/powershell/powershell-control-structures.html" title="PowerShell 控制结构">
#          PowerShell 控制...
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/powershell/powershell-variables-and-scope.html" title="PowerShell 变量和作用域">
#          PowerShell 变量...
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="http://www.runoob.com/powershell/powershell-pipeline-filtering.html" title="PowerShell 管道和过滤">
#          PowerShell 管道...
#         </a>
#        </dd>
#       </dl>
#       <dl>
#        <dt>
#         站点信息
#        </dt>
#        <dd>
#         ·
#         <a href="mailto:admin@runoob.com" rel="external nofollow" target="_blank">
#          意见反馈
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/disclaimer" target="_blank">
#          免责声明
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/aboutus" target="_blank">
#          关于我们
#         </a>
#        </dd>
#        <dd>
#         ·
#         <a href="/archives" target="_blank">
#          文章归档
#         </a>
#        </dd>
#       </dl>
#       <div class="search-share">
#        <div class="app-download">
#         <div>
#          <strong>
#           关注微信
#          </strong>
#         </div>
#        </div>
#        <div class="share">
#         <img height="128" src="/wp-content/themes/runoob/assets/images/qrcode.png" width="128">
#         </img>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="w-1000 copyright">
#      Copyright © 2013-2025
#      <strong>
#       <a href="//www.runoob.com/" target="_blank">
#        菜鸟教程
#       </a>
#      </strong>
#      <strong>
#       <a href="//www.runoob.com/" target="_blank">
#        runoob.com
#       </a>
#      </strong>
#      All Rights Reserved. 备案号：
#      <a href="https://beian.miit.gov.cn/" rel="nofollow" target="_blank">
#       闽ICP备15012807号-1
#      </a>
#     </div>
#    </div>
#    <div class="fixed-btn">
#     <a class="go-top" href="javascript:void(0)" title="返回顶部">
#      <i class="fa fa-angle-up">
#      </i>
#     </a>
#     <a class="qrcode" href="javascript:void(0)" title="关注我们">
#      <i class="fa fa-qrcode">
#      </i>
#     </a>
#     <a class="writer" href="javascript:void(0)" style="display:none" title="标记/收藏">
#      <i aria-hidden="true" class="fa fa-star">
#      </i>
#     </a>
#     <!-- qrcode modal -->
#     <div class="modal panel-modal hide fade in" id="bottom-qrcode">
#      <h4>
#       微信关注
#      </h4>
#      <div class="panel-body">
#       <img alt="微信关注" height="128" src="/wp-content/themes/runoob/assets/images/qrcode.png" width="128"/>
#      </div>
#     </div>
#    </div>
#    <div style="display:none;">
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-84264393-2">
#     </script>
#     <script>
#      window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-84264393-2');
#     </script>
#     <script>
#      var _hmt = _hmt || [];
# (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?3eec0b7da6548cf07db3bc477ea905ee";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();
#     </script>
#    </div>
#    <script>
#     window.jsui={
#     www: 'https://www.runoob.com',
#     uri: 'https://www.runoob.com/wp-content/themes/runoob'
# };
#    </script>
#    <script src="https://static.jyshare.com/assets/libs/clipboard.min.js">
#    </script>
#    <script src="https://static.jyshare.com/assets/libs/hl/run_prettify.js?v=1.173">
#    </script>
#    <script src="/wp-content/themes/runoob/assets/js/main.min.js?v=1.173">
#    </script>
#    <script src="https://static.jyshare.com/assets/libs/marked.umd.js">
#    </script>
#   </link>
#  </body>
# </html>

# %%
soup = BeautifulSoup(format_html, features="html.parser")

# 使用类缩小搜索范围
herf_class = soup.find_all('ul',{"class":"double-li"})
# print(herf_class)
# 提取所有信息
link_data = [(link.get('href'), link.get('title'), link.get_text(strip=True)) 
             for ul in herf_class 
             for link in ul.find_all('a')]

# 打印结果
for href, title, text in link_data:
    print(f"链接: {href}")
    print(f"标题: {title}")
    print(f"文本: {text}")
    print("-" * 50)

herf_list = soup.find_all('a')
# print(herf_list,end='\n\n')

#提取所有类型的链接
# all_herf = [l['href'] for l in herf_list if l['href'].startswith('http') or 'www' in l['href']]
all_herf = [
    'https:' + l['href'] if l['href'].startswith('//') else l['href']
    for l in herf_list
    if l['href'].startswith('http') or 'www' in l['href']
]

for he in all_herf:
    print("链接地址："+he)
# Out:
# 链接: //www.runoob.com/html/html-tutorial.html
# 标题: HTML 教程
# 文本: HTML 教程
# --------------------------------------------------
# 链接: //www.runoob.com/html/html5-intro.html
# 标题: HTML5 教程
# 文本: HTML5 教程
# --------------------------------------------------
# 链接: //www.runoob.com/css/css-tutorial.html
# 标题: CSS 教程
# 文本: CSS 教程
# --------------------------------------------------
# 链接: //www.runoob.com/css3/css3-tutorial.html
# 标题: CSS3 教程
# 文本: CSS3 教程
# --------------------------------------------------
# 链接: //www.runoob.com/tailwindcss/tailwindcss-tutorial.html
# 标题: Tailwind CSS 教程
# 文本: Tailwind CSS 教程
# --------------------------------------------------
# 链接: //www.runoob.com/bootstrap4/bootstrap4-tutorial.html
# 标题: Bootstrap4 教程
# 文本: Bootstrap4 教程
# --------------------------------------------------
# 链接: //www.runoob.com/bootstrap5/bootstrap5-tutorial.html
# 标题: Bootstrap5 教程
# 文本: Bootstrap5 教程
# --------------------------------------------------
# 链接: //www.runoob.com/font-awesome/fontawesome-tutorial.html
# 标题: Font Awesome 教程
# 文本: Font Awesome 教程
# --------------------------------------------------
# 链接: //www.runoob.com/foundation/foundation-tutorial.html
# 标题: Foundation 教程
# 文本: Foundation 教程
# --------------------------------------------------
# 链接: //www.runoob.com/js/js-tutorial.html
# 标题: JavaScript 教程
# 文本: JavaScript 教程
# --------------------------------------------------
# 链接: //www.runoob.com/htmldom/htmldom-tutorial.html
# 标题: HTML DOM 教程
# 文本: HTML DOM 教程
# --------------------------------------------------
# 链接: //www.runoob.com/jquery/jquery-tutorial.html
# 标题: jQuery 教程
# 文本: jQuery 教程
# --------------------------------------------------
# 链接: //www.runoob.com/angularjs/angularjs-tutorial.html
# 标题: AngularJS 教程
# 文本: AngularJS 教程
# --------------------------------------------------
# 链接: //www.runoob.com/angularjs2/angularjs2-tutorial.html
# 标题: AngularJS2 教程
# 文本: AngularJS2 教程
# --------------------------------------------------
# 链接: //www.runoob.com/vue2/vue-tutorial.html
# 标题: Vue.js 教程
# 文本: Vue.js 教程
# --------------------------------------------------
# 链接: //www.runoob.com/vue3/vue3-tutorial.html
# 标题: Vue3 教程
# 文本: Vue3 教程
# --------------------------------------------------
# 链接: //www.runoob.com/react/react-tutorial.html
# 标题: React 教程
# 文本: React 教程
# --------------------------------------------------
# 链接: //www.runoob.com/nextjs/nextjs-tutorial.html
# 标题: Next.js 教程
# 文本: Next.js 教程
# --------------------------------------------------
# 链接: //www.runoob.com/typescript/ts-tutorial.html
# 标题: TypeScript 教程
# 文本: TypeScript 教程
# --------------------------------------------------
# 链接: //www.runoob.com/jqueryui/jqueryui-tutorial.html
# 标题: jQuery UI 教程
# 文本: jQuery UI 教程
# --------------------------------------------------
# 链接: //www.runoob.com/jeasyui/jqueryeasyui-tutorial.html
# 标题: jQuery EasyUI 教程
# 文本: jQuery EasyUI 教程
# --------------------------------------------------
# 链接: //www.runoob.com/nodejs/nodejs-tutorial.html
# 标题: Node.js 教程
# 文本: Node.js 教程
# --------------------------------------------------
# 链接: //www.runoob.com/ajax/ajax-tutorial.html
# 标题: AJAX 教程
# 文本: AJAX 教程
# --------------------------------------------------
# 链接: //www.runoob.com/json/json-tutorial.html
# 标题: JSON 教程
# 文本: JSON 教程
# --------------------------------------------------
# 链接: //www.runoob.com/echarts/echarts-tutorial.html
# 标题: Echarts 教程
# 文本: Echarts 教程
# --------------------------------------------------
# 链接: //www.runoob.com/chartjs/chartjs-tutorial.html
# 标题: Chart.js 教程
# 文本: Chart.js 教程
# --------------------------------------------------
# 链接: //www.runoob.com/highcharts/highcharts-tutorial.html
# 标题: Highcharts 教程
# 文本: Highcharts 教程
# --------------------------------------------------
# 链接: //www.runoob.com/googleapi/google-maps-basic.html
# 标题: Google 地图 教程
# 文本: Google 地图 教程
# --------------------------------------------------
# 链接: //www.runoob.com/python3/python3-tutorial.html
# 标题: Python 教程
# 文本: Python 教程
# --------------------------------------------------
# 链接: //www.runoob.com/python/python-tutorial.html
# 标题: Python2.x 教程
# 文本: Python2.x 教程
# --------------------------------------------------
# 链接: //www.runoob.com/linux/linux-tutorial.html
# 标题: Linux 教程
# 文本: Linux 教程
# --------------------------------------------------
# 链接: //www.runoob.com/docker/docker-tutorial.html
# 标题: Docker 教程
# 文本: Docker 教程
# --------------------------------------------------
# 链接: //www.runoob.com/ruby/ruby-tutorial.html
# 标题: Ruby 教程
# 文本: Ruby 教程
# --------------------------------------------------
# 链接: //www.runoob.com/java/java-tutorial.html
# 标题: Java 教程
# 文本: Java 教程
# --------------------------------------------------
# 链接: //www.runoob.com/c/c-tutorial.html
# 标题: C 教程
# 文本: C 教程
# --------------------------------------------------
# 链接: //www.runoob.com/cplusplus/cpp-tutorial.html
# 标题: C++ 教程
# 文本: C++ 教程
# --------------------------------------------------
# 链接: //www.runoob.com/perl/perl-tutorial.html
# 标题: Perl 教程
# 文本: Perl 教程
# --------------------------------------------------
# 链接: //www.runoob.com/servlet/servlet-tutorial.html
# 标题: Servlet 教程
# 文本: Servlet 教程
# --------------------------------------------------
# 链接: //www.runoob.com/jsp/jsp-tutorial.html
# 标题: JSP 教程
# 文本: JSP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/lua/lua-tutorial.html
# 标题: Lua 教程
# 文本: Lua 教程
# --------------------------------------------------
# 链接: //www.runoob.com/rust/rust-tutorial.html
# 标题: Rust 教程
# 文本: Rust 教程
# --------------------------------------------------
# 链接: //www.runoob.com/zig/zig-tutorial.html
# 标题: Zig 教程
# 文本: Zig 教程
# --------------------------------------------------
# 链接: //www.runoob.com/scala/scala-tutorial.html
# 标题: Scala 教程
# 文本: Scala 教程
# --------------------------------------------------
# 链接: //www.runoob.com/go/go-tutorial.html
# 标题: Go 教程
# 文本: Go 教程
# --------------------------------------------------
# 链接: //www.runoob.com/php/php-tutorial.html
# 标题: PHP 教程
# 文本: PHP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/data-structures/data-structures-tutorial.html
# 标题: 数据结构与算法
# 文本: 数据结构与算法
# --------------------------------------------------
# 链接: //www.runoob.com/django/django-tutorial.html
# 标题: Django 教程
# 文本: Django 教程
# --------------------------------------------------
# 链接: //www.runoob.com/fastapi/fastapi-tutorial.html
# 标题: FastAPI 教程
# 文本: FastAPI 教程
# --------------------------------------------------
# 链接: //www.runoob.com/flask/flask-tutorial.html
# 标题: Flask 教程
# 文本: Flask 教程
# --------------------------------------------------
# 链接: //www.runoob.com/pillow/pillow-tutorial.html
# 标题: Pillow 教程
# 文本: Pillow 教程
# --------------------------------------------------
# 链接: //www.runoob.com/w3cnote/zookeeper-tutorial.html
# 标题: Zookeeper 教程
# 文本: Zookeeper 教程
# --------------------------------------------------
# 链接: //www.runoob.com/design-pattern/design-pattern-tutorial.html
# 标题: 设计模式
# 文本: 设计模式
# --------------------------------------------------
# 链接: //www.runoob.com/regexp/regexp-tutorial.html
# 标题: 正则表达式
# 文本: 正则表达式
# --------------------------------------------------
# 链接: //www.runoob.com/maven/maven-tutorial.html
# 标题: Maven 教程
# 文本: Maven 教程
# --------------------------------------------------
# 链接: //www.runoob.com/cmake/cmake-tutorial.html
# 标题: CMake 教程
# 文本: CMake 教程
# --------------------------------------------------
# 链接: //www.runoob.com/w3cnote/verilog-tutorial.html
# 标题: Verilog 教程
# 文本: Verilog 教程
# --------------------------------------------------
# 链接: //www.runoob.com/asp/asp-tutorial.html
# 标题: ASP 教程
# 文本: ASP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/appml/appml-tutorial.html
# 标题: AppML 教程
# 文本: AppML 教程
# --------------------------------------------------
# 链接: //www.runoob.com/vbscript/vbscript-tutorial.html
# 标题: VBScript 教程
# 文本: VBScript 教程
# --------------------------------------------------
# 链接: //www.runoob.com/sql/sql-tutorial.html
# 标题: SQL 教程
# 文本: SQL 教程
# --------------------------------------------------
# 链接: //www.runoob.com/mysql/mysql-tutorial.html
# 标题: MySQL 教程
# 文本: MySQL 教程
# --------------------------------------------------
# 链接: //www.runoob.com/postgresql/postgresql-tutorial.html
# 标题: PostgreSQL 教程
# 文本: PostgreSQL 教程
# --------------------------------------------------
# 链接: //www.runoob.com/sqlite/sqlite-tutorial.html
# 标题: SQLite 教程
# 文本: SQLite 教程
# --------------------------------------------------
# 链接: //www.runoob.com/mongodb/mongodb-tutorial.html
# 标题: MongoDB 教程
# 文本: MongoDB 教程
# --------------------------------------------------
# 链接: //www.runoob.com/redis/redis-tutorial.html
# 标题: Redis 教程
# 文本: Redis 教程
# --------------------------------------------------
# 链接: //www.runoob.com/Memcached/Memcached-tutorial.html
# 标题: Memcached 教程
# 文本: Memcached 教程
# --------------------------------------------------
# 链接: //www.runoob.com/python3/python3-tutorial.html
# 标题: Python 教程
# 文本: Python 教程
# --------------------------------------------------
# 链接: //www.runoob.com/numpy/numpy-tutorial.html
# 标题: NumPy 教程
# 文本: NumPy 教程
# --------------------------------------------------
# 链接: //www.runoob.com/pandas/pandas-tutorial.html
# 标题: Pandas 教程
# 文本: Pandas 教程
# --------------------------------------------------
# 链接: //www.runoob.com/matplotlib/matplotlib-tutorial.html
# 标题: Matplotlib 教程
# 文本: Matplotlib 教程
# --------------------------------------------------
# 链接: //www.runoob.com/scipy/scipy-tutorial.html
# 标题: Scipy 教程
# 文本: Scipy 教程
# --------------------------------------------------
# 链接: //www.runoob.com/pytorch/pytorch-tutorial.html
# 标题: Pytorch 教程
# 文本: Pytorch 教程
# --------------------------------------------------
# 链接: //www.runoob.com/tensorflow/tensorflow-tutorial.html
# 标题: TensorFlow 教程
# 文本: TensorFlow 教程
# --------------------------------------------------
# 链接: //www.runoob.com/ollama/ollama-tutorial.html
# 标题: Ollama 教程
# 文本: Ollama 教程
# --------------------------------------------------
# 链接: //www.runoob.com/ml/ml-tutorial.html
# 标题: 机器 教程
# 文本: 机器 教程
# --------------------------------------------------
# 链接: //www.runoob.com/sklearn/sklearn-tutorial.html
# 标题: scikit-learn 教程
# 文本: scikit-learn 教程
# --------------------------------------------------
# 链接: //www.runoob.com/r/r-tutorial.html
# 标题: R 教程
# 文本: R 教程
# --------------------------------------------------
# 链接: //www.runoob.com/opencv/opencv-tutorial.html
# 标题: OpenCV 教程
# 文本: OpenCV 教程
# --------------------------------------------------
# 链接: //www.runoob.com/nlp/nlp-tutorial.html
# 标题: NLP 教程
# 文本: NLP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/selenium/selenium-tutorial.html
# 标题: Selenium 教程
# 文本: Selenium 教程
# --------------------------------------------------
# 链接: //www.runoob.com/julia/julia-tutorial.html
# 标题: Julia 教程
# 文本: Julia 教程
# --------------------------------------------------
# 链接: //www.runoob.com/qt/qt-tutorial.html
# 标题: 量化交易
# 文本: 量化交易
# --------------------------------------------------
# 链接: //www.runoob.com/dash/dash-tutorial.html
# 标题: Dash 教程
# 文本: Dash 教程
# --------------------------------------------------
# 链接: //www.runoob.com/w3cnote/android-tutorial-intro.html
# 标题: Android 教程
# 文本: Android 教程
# --------------------------------------------------
# 链接: //www.runoob.com/swift/swift-tutorial.html
# 标题: Swift 教程
# 文本: Swift 教程
# --------------------------------------------------
# 链接: //www.runoob.com/jquerymobile/jquerymobile-tutorial.html
# 标题: jQuery Mobile 教程
# 文本: jQuery Mobile 教程
# --------------------------------------------------
# 链接: //www.runoob.com/ionic/ionic-tutorial.html
# 标题: ionic 教程
# 文本: ionic 教程
# --------------------------------------------------
# 链接: //www.runoob.com/kotlin/kotlin-tutorial.html
# 标题: Kotlin 教程
# 文本: Kotlin 教程
# --------------------------------------------------
# 链接: //www.runoob.com/vscode/vscode-tutorial.html
# 标题: VS Code 教程
# 文本: VS Code 教程
# --------------------------------------------------
# 链接: //www.runoob.com/pycharm/pycharm-tutorial.html
# 标题: PyCharm 教程
# 文本: PyCharm 教程
# --------------------------------------------------
# 链接: //www.runoob.com/swagger/swagger-tutorial.html
# 标题: Swagger 教程
# 文本: Swagger 教程
# --------------------------------------------------
# 链接: //www.runoob.com/restfulapi/restful-api-tutorial.html
# 标题: RESTful API 教程
# 文本: RESTful API 教程
# --------------------------------------------------
# 链接: //www.runoob.com/eclipse/eclipse-tutorial.html
# 标题: Eclipse 教程
# 文本: Eclipse 教程
# --------------------------------------------------
# 链接: //www.runoob.com/git/git-tutorial.html
# 标题: Git 教程
# 文本: Git 教程
# --------------------------------------------------
# 链接: //www.runoob.com/svn/svn-tutorial.html
# 标题: Svn 教程
# 文本: Svn 教程
# --------------------------------------------------
# 链接: //www.runoob.com/markdown/md-tutorial.html
# 标题: Markdown 教程
# 文本: Markdown 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xml/xml-tutorial.html
# 标题: XML 教程
# 文本: XML 教程
# --------------------------------------------------
# 链接: //www.runoob.com/dtd/dtd-tutorial.html
# 标题: DTD 教程
# 文本: DTD 教程
# --------------------------------------------------
# 链接: //www.runoob.com/dom/dom-tutorial.html
# 标题: XML DOM 教程
# 文本: XML DOM 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xsl/xsl-tutorial.html
# 标题: XSLT 教程
# 文本: XSLT 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xpath/xpath-tutorial.html
# 标题: XPath 教程
# 文本: XPath 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xquery/xquery-tutorial.html
# 标题: XQuery 教程
# 文本: XQuery 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xlink/xlink-tutorial.html
# 标题: XLink 教程
# 文本: XLink 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xlink/xlink-tutorial.html
# 标题: XPointer 教程
# 文本: XPointer 教程
# --------------------------------------------------
# 链接: //www.runoob.com/schema/schema-tutorial.html
# 标题: XML Schema 教程
# 文本: XML Schema 教程
# --------------------------------------------------
# 链接: //www.runoob.com/xslfo/xslfo-tutorial.html
# 标题: XSL-FO 教程
# 文本: XSL-FO 教程
# --------------------------------------------------
# 链接: //www.runoob.com/svg/svg-tutorial.html
# 标题: SVG 教程
# 文本: SVG 教程
# --------------------------------------------------
# 链接: //www.runoob.com/aspnet/aspnet-tutorial.html
# 标题: ASP.NET 教程
# 文本: ASP.NET 教程
# --------------------------------------------------
# 链接: //www.runoob.com/csharp/csharp-tutorial.html
# 标题: C# 教程
# 文本: C# 教程
# --------------------------------------------------
# 链接: //www.runoob.com/powershell/powershell-tutorial.html
# 标题: PowerShell 教程
# 文本: PowerShell 教程
# --------------------------------------------------
# 链接: //www.runoob.com/aspnet/webpages-intro.html
# 标题: Web Pages 教程
# 文本: Web Pages 教程
# --------------------------------------------------
# 链接: //www.runoob.com/aspnet/razor-intro.html
# 标题: Razor 教程
# 文本: Razor 教程
# --------------------------------------------------
# 链接: //www.runoob.com/aspnet/mvc-intro.html
# 标题: MVC 教程
# 文本: MVC 教程
# --------------------------------------------------
# 链接: //www.runoob.com/aspnet/aspnet-intro.html
# 标题: Web Forms 教程
# 文本: Web Forms 教程
# --------------------------------------------------
# 链接: //www.runoob.com/webservices/webservices-tutorial.html
# 标题: Web Service 教程
# 文本: Web Service 教程
# --------------------------------------------------
# 链接: //www.runoob.com/wsdl/wsdl-tutorial.html
# 标题: WSDL 教程
# 文本: WSDL 教程
# --------------------------------------------------
# 链接: //www.runoob.com/soap/soap-tutorial.html
# 标题: SOAP 教程
# 文本: SOAP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/rss/rss-tutorial.html
# 标题: RSS 教程
# 文本: RSS 教程
# --------------------------------------------------
# 链接: //www.runoob.com/rdf/rdf-tutorial.html
# 标题: RDF 教程
# 文本: RDF 教程
# --------------------------------------------------
# 链接: //www.runoob.com/http/http-tutorial.html
# 标题: HTTP 教程
# 文本: HTTP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/web/web-buildingprimer.html
# 标题: 网站建设指南
# 文本: 网站建设指南
# --------------------------------------------------
# 链接: //www.runoob.com/browsers/browser-information.html
# 标题: 浏览器信息
# 文本: 浏览器信息
# --------------------------------------------------
# 链接: //www.runoob.com/np/np-tutorial.html
# 标题: 网络协议
# 文本: 网络协议
# --------------------------------------------------
# 链接: //www.runoob.com/hosting/hosting-tutorial.html
# 标题: 网站主机教程
# 文本: 网站主机教程
# --------------------------------------------------
# 链接: //www.runoob.com/tcpip/tcpip-tutorial.html
# 标题: TCP/IP 教程
# 文本: TCP/IP 教程
# --------------------------------------------------
# 链接: //www.runoob.com/w3c/w3c-tutorial.html
# 标题: W3C 教程
# 文本: W3C 教程
# --------------------------------------------------
# 链接: //www.runoob.com/quality/quality-tutorial.html
# 标题: 网站品质
# 文本: 网站品质
# --------------------------------------------------
# 链接地址：https://www.runoob.com/
# 链接地址：https://www.runoob.com/
# 链接地址：http://www.runoob.com/markdown/md-title.html
# 链接地址：https://union-click.jd.com/jdc?e=618%7Cpc%7C&p=JF8BAM0JK1olXwUFU1xdCE4TBl8IGFwSVQUEUW4ZVxNJXF9RXh5UHw0cSgYYXBcIWDoXSQVJQwYBU1lVC00SHDZNRwYlIXBjCCEWQUl0dmhjaBBFWVp7FABVXkcbM244GFkUXwYyZF5aOBl529m-w_6kQdKo24vVn3sWM28PHV0cVQ4GVl5aAE0nBG8BKx5NDVlCDBcFV3snM2w4HFscSQBwFQxJDjknM284GGsVVA4DV15dAU8LA24LGVMJXQEEUldVAE4eAG0PHWsXXAcGXW5t
# 链接地址：http://www.runoob.com/markdown/md-title.html
# 链接地址：https://www.runoob.com/html/html-tutorial.html
# 链接地址：https://www.runoob.com/html/html5-intro.html
# 链接地址：https://www.runoob.com/css/css-tutorial.html
# 链接地址：https://www.runoob.com/css3/css3-tutorial.html
# 链接地址：https://www.runoob.com/tailwindcss/tailwindcss-tutorial.html
# 链接地址：https://www.runoob.com/bootstrap4/bootstrap4-tutorial.html
# 链接地址：https://www.runoob.com/bootstrap5/bootstrap5-tutorial.html
# 链接地址：https://www.runoob.com/font-awesome/fontawesome-tutorial.html
# 链接地址：https://www.runoob.com/foundation/foundation-tutorial.html
# 链接地址：https://www.runoob.com/js/js-tutorial.html
# 链接地址：https://www.runoob.com/htmldom/htmldom-tutorial.html
# 链接地址：https://www.runoob.com/jquery/jquery-tutorial.html
# 链接地址：https://www.runoob.com/angularjs/angularjs-tutorial.html
# 链接地址：https://www.runoob.com/angularjs2/angularjs2-tutorial.html
# 链接地址：https://www.runoob.com/vue2/vue-tutorial.html
# 链接地址：https://www.runoob.com/vue3/vue3-tutorial.html
# 链接地址：https://www.runoob.com/react/react-tutorial.html
# 链接地址：https://www.runoob.com/nextjs/nextjs-tutorial.html
# 链接地址：https://www.runoob.com/typescript/ts-tutorial.html
# 链接地址：https://www.runoob.com/jqueryui/jqueryui-tutorial.html
# 链接地址：https://www.runoob.com/jeasyui/jqueryeasyui-tutorial.html
# 链接地址：https://www.runoob.com/nodejs/nodejs-tutorial.html
# 链接地址：https://www.runoob.com/ajax/ajax-tutorial.html
# 链接地址：https://www.runoob.com/json/json-tutorial.html
# 链接地址：https://www.runoob.com/echarts/echarts-tutorial.html
# 链接地址：https://www.runoob.com/chartjs/chartjs-tutorial.html
# 链接地址：https://www.runoob.com/highcharts/highcharts-tutorial.html
# 链接地址：https://www.runoob.com/googleapi/google-maps-basic.html
# 链接地址：https://www.runoob.com/python3/python3-tutorial.html
# 链接地址：https://www.runoob.com/python/python-tutorial.html
# 链接地址：https://www.runoob.com/linux/linux-tutorial.html
# 链接地址：https://www.runoob.com/docker/docker-tutorial.html
# 链接地址：https://www.runoob.com/ruby/ruby-tutorial.html
# 链接地址：https://www.runoob.com/java/java-tutorial.html
# 链接地址：https://www.runoob.com/c/c-tutorial.html
# 链接地址：https://www.runoob.com/cplusplus/cpp-tutorial.html
# 链接地址：https://www.runoob.com/perl/perl-tutorial.html
# 链接地址：https://www.runoob.com/servlet/servlet-tutorial.html
# 链接地址：https://www.runoob.com/jsp/jsp-tutorial.html
# 链接地址：https://www.runoob.com/lua/lua-tutorial.html
# 链接地址：https://www.runoob.com/rust/rust-tutorial.html
# 链接地址：https://www.runoob.com/zig/zig-tutorial.html
# 链接地址：https://www.runoob.com/scala/scala-tutorial.html
# 链接地址：https://www.runoob.com/go/go-tutorial.html
# 链接地址：https://www.runoob.com/php/php-tutorial.html
# 链接地址：https://www.runoob.com/data-structures/data-structures-tutorial.html
# 链接地址：https://www.runoob.com/django/django-tutorial.html
# 链接地址：https://www.runoob.com/fastapi/fastapi-tutorial.html
# 链接地址：https://www.runoob.com/flask/flask-tutorial.html
# 链接地址：https://www.runoob.com/pillow/pillow-tutorial.html
# 链接地址：https://www.runoob.com/w3cnote/zookeeper-tutorial.html
# 链接地址：https://www.runoob.com/design-pattern/design-pattern-tutorial.html
# 链接地址：https://www.runoob.com/regexp/regexp-tutorial.html
# 链接地址：https://www.runoob.com/maven/maven-tutorial.html
# 链接地址：https://www.runoob.com/cmake/cmake-tutorial.html
# 链接地址：https://www.runoob.com/w3cnote/verilog-tutorial.html
# 链接地址：https://www.runoob.com/asp/asp-tutorial.html
# 链接地址：https://www.runoob.com/appml/appml-tutorial.html
# 链接地址：https://www.runoob.com/vbscript/vbscript-tutorial.html
# 链接地址：https://www.runoob.com/sql/sql-tutorial.html
# 链接地址：https://www.runoob.com/mysql/mysql-tutorial.html
# 链接地址：https://www.runoob.com/postgresql/postgresql-tutorial.html
# 链接地址：https://www.runoob.com/sqlite/sqlite-tutorial.html
# 链接地址：https://www.runoob.com/mongodb/mongodb-tutorial.html
# 链接地址：https://www.runoob.com/redis/redis-tutorial.html
# 链接地址：https://www.runoob.com/Memcached/Memcached-tutorial.html
# 链接地址：https://www.runoob.com/python3/python3-tutorial.html
# 链接地址：https://www.runoob.com/numpy/numpy-tutorial.html
# 链接地址：https://www.runoob.com/pandas/pandas-tutorial.html
# 链接地址：https://www.runoob.com/matplotlib/matplotlib-tutorial.html
# 链接地址：https://www.runoob.com/scipy/scipy-tutorial.html
# 链接地址：https://www.runoob.com/pytorch/pytorch-tutorial.html
# 链接地址：https://www.runoob.com/tensorflow/tensorflow-tutorial.html
# 链接地址：https://www.runoob.com/ollama/ollama-tutorial.html
# 链接地址：https://www.runoob.com/ml/ml-tutorial.html
# 链接地址：https://www.runoob.com/sklearn/sklearn-tutorial.html
# 链接地址：https://www.runoob.com/r/r-tutorial.html
# 链接地址：https://www.runoob.com/opencv/opencv-tutorial.html
# 链接地址：https://www.runoob.com/nlp/nlp-tutorial.html
# 链接地址：https://www.runoob.com/selenium/selenium-tutorial.html
# 链接地址：https://www.runoob.com/julia/julia-tutorial.html
# 链接地址：https://www.runoob.com/qt/qt-tutorial.html
# 链接地址：https://www.runoob.com/dash/dash-tutorial.html
# 链接地址：https://www.runoob.com/w3cnote/android-tutorial-intro.html
# 链接地址：https://www.runoob.com/swift/swift-tutorial.html
# 链接地址：https://www.runoob.com/jquerymobile/jquerymobile-tutorial.html
# 链接地址：https://www.runoob.com/ionic/ionic-tutorial.html
# 链接地址：https://www.runoob.com/kotlin/kotlin-tutorial.html
# 链接地址：https://www.runoob.com/vscode/vscode-tutorial.html
# 链接地址：https://www.runoob.com/pycharm/pycharm-tutorial.html
# 链接地址：https://www.runoob.com/swagger/swagger-tutorial.html
# 链接地址：https://www.runoob.com/restfulapi/restful-api-tutorial.html
# 链接地址：https://www.runoob.com/eclipse/eclipse-tutorial.html
# 链接地址：https://www.runoob.com/git/git-tutorial.html
# 链接地址：https://www.runoob.com/svn/svn-tutorial.html
# 链接地址：https://www.runoob.com/markdown/md-tutorial.html
# 链接地址：https://www.runoob.com/xml/xml-tutorial.html
# 链接地址：https://www.runoob.com/dtd/dtd-tutorial.html
# 链接地址：https://www.runoob.com/dom/dom-tutorial.html
# 链接地址：https://www.runoob.com/xsl/xsl-tutorial.html
# 链接地址：https://www.runoob.com/xpath/xpath-tutorial.html
# 链接地址：https://www.runoob.com/xquery/xquery-tutorial.html
# 链接地址：https://www.runoob.com/xlink/xlink-tutorial.html
# 链接地址：https://www.runoob.com/xlink/xlink-tutorial.html
# 链接地址：https://www.runoob.com/schema/schema-tutorial.html
# 链接地址：https://www.runoob.com/xslfo/xslfo-tutorial.html
# 链接地址：https://www.runoob.com/svg/svg-tutorial.html
# 链接地址：https://www.runoob.com/aspnet/aspnet-tutorial.html
# 链接地址：https://www.runoob.com/csharp/csharp-tutorial.html
# 链接地址：https://www.runoob.com/powershell/powershell-tutorial.html
# 链接地址：https://www.runoob.com/aspnet/webpages-intro.html
# 链接地址：https://www.runoob.com/aspnet/razor-intro.html
# 链接地址：https://www.runoob.com/aspnet/mvc-intro.html
# 链接地址：https://www.runoob.com/aspnet/aspnet-intro.html
# 链接地址：https://www.runoob.com/webservices/webservices-tutorial.html
# 链接地址：https://www.runoob.com/wsdl/wsdl-tutorial.html
# 链接地址：https://www.runoob.com/soap/soap-tutorial.html
# 链接地址：https://www.runoob.com/rss/rss-tutorial.html
# 链接地址：https://www.runoob.com/rdf/rdf-tutorial.html
# 链接地址：https://www.runoob.com/http/http-tutorial.html
# 链接地址：https://www.runoob.com/web/web-buildingprimer.html
# 链接地址：https://www.runoob.com/browsers/browser-information.html
# 链接地址：https://www.runoob.com/np/np-tutorial.html
# 链接地址：https://www.runoob.com/hosting/hosting-tutorial.html
# 链接地址：https://www.runoob.com/tcpip/tcpip-tutorial.html
# 链接地址：https://www.runoob.com/w3c/w3c-tutorial.html
# 链接地址：https://www.runoob.com/quality/quality-tutorial.html
# 链接地址：https://www.jyshare.com/front-end/6939/
# 链接地址：https://www.jyshare.com/front-end/6232/
# 链接地址：https://www.jyshare.com/front-end/53
# 链接地址：https://www.jyshare.com/front-end/6680/
# 链接地址：http://www.runoob.com/vscode/vscode-mcp-servers.html
# 链接地址：http://www.runoob.com/linux/windows-wsl-linux.html
# 链接地址：http://www.runoob.com/powershell/powershell-practice.html
# 链接地址：http://www.runoob.com/powershell/powershell-script.html
# 链接地址：http://www.runoob.com/powershell/powershell-control-structures.html
# 链接地址：http://www.runoob.com/powershell/powershell-variables-and-scope.html
# 链接地址：http://www.runoob.com/powershell/powershell-pipeline-filtering.html
# 链接地址：https://www.runoob.com/
# 链接地址：https://www.runoob.com/
# 链接地址：https://beian.miit.gov.cn/
